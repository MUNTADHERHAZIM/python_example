# %%
from nnv import NNV  # مكتبه الرسم البياني للشبكة العصبية الاصطناعية 

layersList = [
    {"title":"input\n(relu)", "units": 20, "color": "darkBlue"},
    {"title":"hidden 1\n(relu)", "units": 10},
    {"title":"hidden 2\n(relu)", "units": 10, "edges_color":"red", "edges_width":2},
    {"title":"output\n(sigmoid)", "units": 2,"color": "darkred"},
]

NNV(layersList).render(save_to_file="my_example.png")
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot: >)

# %%
from nnv import NNV # استدعاء مكتبه الرسم الشبكة العصبية الاصطناعية  

# Let's increase the size of the plot
import matplotlib.pyplot as plt  # استدعاء مكتبة الرسم 
plt.rcParams["figure.figsize"] = (100,20) # تعديل حجم الرسم 


layers_list = [ # تعريف الطبقات 
    {"title":"input\n(relu)", "units": 300, "color": "darkBlue"}, # الطبقة الاولى
    {"title":"hidden 1\n(relu)", "units": 150}, 
    {"title":"hidden 2\n(relu)",  "units": 75},
    {"title":"Dropout\n(0.5)", "units": 75,"color":"lightBlue"},      # الخمس طبقات الاخرى
    {"title":"hidden 4\n(relu)",  "units": 18},
    {"title":"hidden 5\n(relu)",  "units": 9},
    {"title":"hidden 6\n(relu)",  "units": 4},
    {"title":"output\n(sigmoid)", "units": 2,"color": "darkred"}, # الطبقة الاخيرة
]


NNV(layers_list, max_num_nodes_visible=10, node_radius=10, spacing_layer=60, font_size=24).render(save_to_file="my_example_2.png") 
# رسم الشبكة العصبية الاصطناعية
# Out:
# (<Figure size 10000x2000 with 1 Axes>, <AxesSubplot: >)
